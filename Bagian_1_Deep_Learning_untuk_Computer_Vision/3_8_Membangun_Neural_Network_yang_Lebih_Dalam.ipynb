# %% [markdown]
# <a href="https://colab.research.google.com/github/ksnugroho/teori-praktik-cv-part1/blob/main/Bagian_1_Bab_3_3_8_Membangun_Neural_Network_yang_Lebih_Dalam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from torch.optim import SGD, Adam
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Mengunduh Dataset

# %%
data_folder = './data/FMNIST'

train_data = datasets.FashionMNIST(data_folder, download=True, train=True)
val_data = datasets.FashionMNIST(data_folder, download=True, train=False)

tr_images, tr_targets = train_data.data, train_data.targets
val_images, val_targets = val_data.data, val_data.targets
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:00<00:00, 117MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 5.12MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 66.2MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 18.3MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw

# %%
class FMNISTDataset(Dataset):
    def __init__(self, x, y):
        x = x.float() / 255
        x = x.view(-1, 28*28)
        self.x, self.y = x, y

    def __getitem__(self, ix):
        x, y = self.x[ix], self.y[ix]
        return x.to(device), y.to(device)

    def __len__(self):
        return len(self.x)

# %% [markdown]
# # Model tanpa Hidden Layer

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Tanpa hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28*28, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    batch_loss = loss_fn(prediction, y)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.5965, Train Accuracy: 0.8376
# Validation Loss: 0.5142, Validation Accuracy: 0.8248
# Epoch 2
# Train Loss: 0.4600, Train Accuracy: 0.8505
# Validation Loss: 0.4773, Validation Accuracy: 0.8332
# Epoch 3
# Train Loss: 0.4360, Train Accuracy: 0.8528
# Validation Loss: 0.4765, Validation Accuracy: 0.8367
# Epoch 4
# Train Loss: 0.4215, Train Accuracy: 0.8475
# Validation Loss: 0.4796, Validation Accuracy: 0.8304
# Epoch 5
# Train Loss: 0.4126, Train Accuracy: 0.8581
# Validation Loss: 0.4568, Validation Accuracy: 0.8410
# Epoch 6
# Train Loss: 0.4064, Train Accuracy: 0.8568
# Validation Loss: 0.4704, Validation Accuracy: 0.8409
# Epoch 7
# Train Loss: 0.4021, Train Accuracy: 0.8663
# Validation Loss: 0.4474, Validation Accuracy: 0.8449
# Epoch 8
# Train Loss: 0.3968, Train Accuracy: 0.8605
# Validation Loss: 0.4582, Validation Accuracy: 0.8405
# Epoch 9
# Train Loss: 0.3935, Train Accuracy: 0.8669
# Validation Loss: 0.4501, Validation Accuracy: 0.8432
# Epoch 10
# Train Loss: 0.3923, Train Accuracy: 0.8570
# Validation Loss: 0.4717, Validation Accuracy: 0.8363
# Epoch 11
# Train Loss: 0.3890, Train Accuracy: 0.8673
# Validation Loss: 0.4462, Validation Accuracy: 0.8454
# Epoch 12
# Train Loss: 0.3865, Train Accuracy: 0.8673
# Validation Loss: 0.4493, Validation Accuracy: 0.8426
# Epoch 13
# Train Loss: 0.3859, Train Accuracy: 0.8668
# Validation Loss: 0.4480, Validation Accuracy: 0.8450
# Epoch 14
# Train Loss: 0.3831, Train Accuracy: 0.8708
# Validation Loss: 0.4407, Validation Accuracy: 0.8473
# Epoch 15
# Train Loss: 0.3818, Train Accuracy: 0.8650
# Validation Loss: 0.4587, Validation Accuracy: 0.8422
# Epoch 16
# Train Loss: 0.3816, Train Accuracy: 0.8690
# Validation Loss: 0.4449, Validation Accuracy: 0.8421
# Epoch 17
# Train Loss: 0.3796, Train Accuracy: 0.8700
# Validation Loss: 0.4469, Validation Accuracy: 0.8432
# Epoch 18
# Train Loss: 0.3786, Train Accuracy: 0.8709
# Validation Loss: 0.4438, Validation Accuracy: 0.8453
# Epoch 19
# Train Loss: 0.3781, Train Accuracy: 0.8712
# Validation Loss: 0.4493, Validation Accuracy: 0.8444
# Epoch 20
# Train Loss: 0.3762, Train Accuracy: 0.8677
# Validation Loss: 0.4509, Validation Accuracy: 0.8401
# Epoch 21
# Train Loss: 0.3746, Train Accuracy: 0.8714
# Validation Loss: 0.4481, Validation Accuracy: 0.8432
# Epoch 22
# Train Loss: 0.3740, Train Accuracy: 0.8633
# Validation Loss: 0.4592, Validation Accuracy: 0.8384
# Epoch 23
# Train Loss: 0.3733, Train Accuracy: 0.8668
# Validation Loss: 0.4535, Validation Accuracy: 0.8411
# Epoch 24
# Train Loss: 0.3721, Train Accuracy: 0.8732
# Validation Loss: 0.4428, Validation Accuracy: 0.8443
# Epoch 25
# Train Loss: 0.3705, Train Accuracy: 0.8748
# Validation Loss: 0.4440, Validation Accuracy: 0.8450
# Epoch 26
# Train Loss: 0.3710, Train Accuracy: 0.8734
# Validation Loss: 0.4484, Validation Accuracy: 0.8435
# Epoch 27
# Train Loss: 0.3693, Train Accuracy: 0.8695
# Validation Loss: 0.4592, Validation Accuracy: 0.8433
# Epoch 28
# Train Loss: 0.3700, Train Accuracy: 0.8751
# Validation Loss: 0.4443, Validation Accuracy: 0.8474
# Epoch 29
# Train Loss: 0.3690, Train Accuracy: 0.8669
# Validation Loss: 0.4577, Validation Accuracy: 0.8393
# Epoch 30
# Train Loss: 0.3687, Train Accuracy: 0.8738
# Validation Loss: 0.4468, Validation Accuracy: 0.8451

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with No Hidden Layer')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with No Hidden Layer')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-6-7c6c315d28ae>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Model dengan Satu Hidden Layer

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Satu hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    batch_loss = loss_fn(prediction, y)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.4742, Train Accuracy: 0.8593
# Validation Loss: 0.4312, Validation Accuracy: 0.8418
# Epoch 2
# Train Loss: 0.3578, Train Accuracy: 0.8811
# Validation Loss: 0.3826, Validation Accuracy: 0.8615
# Epoch 3
# Train Loss: 0.3199, Train Accuracy: 0.8928
# Validation Loss: 0.3649, Validation Accuracy: 0.8728
# Epoch 4
# Train Loss: 0.2945, Train Accuracy: 0.8814
# Validation Loss: 0.3876, Validation Accuracy: 0.8567
# Epoch 5
# Train Loss: 0.2743, Train Accuracy: 0.9075
# Validation Loss: 0.3292, Validation Accuracy: 0.8812
# Epoch 6
# Train Loss: 0.2617, Train Accuracy: 0.9107
# Validation Loss: 0.3296, Validation Accuracy: 0.8832
# Epoch 7
# Train Loss: 0.2480, Train Accuracy: 0.9175
# Validation Loss: 0.3262, Validation Accuracy: 0.8871
# Epoch 8
# Train Loss: 0.2370, Train Accuracy: 0.8992
# Validation Loss: 0.3814, Validation Accuracy: 0.8684
# Epoch 9
# Train Loss: 0.2276, Train Accuracy: 0.9169
# Validation Loss: 0.3540, Validation Accuracy: 0.8812
# Epoch 10
# Train Loss: 0.2181, Train Accuracy: 0.9234
# Validation Loss: 0.3386, Validation Accuracy: 0.8869
# Epoch 11
# Train Loss: 0.2103, Train Accuracy: 0.9254
# Validation Loss: 0.3386, Validation Accuracy: 0.8863
# Epoch 12
# Train Loss: 0.2032, Train Accuracy: 0.9322
# Validation Loss: 0.3252, Validation Accuracy: 0.8912
# Epoch 13
# Train Loss: 0.1956, Train Accuracy: 0.9315
# Validation Loss: 0.3543, Validation Accuracy: 0.8895
# Epoch 14
# Train Loss: 0.1892, Train Accuracy: 0.9334
# Validation Loss: 0.3437, Validation Accuracy: 0.8904
# Epoch 15
# Train Loss: 0.1825, Train Accuracy: 0.9335
# Validation Loss: 0.3552, Validation Accuracy: 0.8897
# Epoch 16
# Train Loss: 0.1763, Train Accuracy: 0.9382
# Validation Loss: 0.3512, Validation Accuracy: 0.8901
# Epoch 17
# Train Loss: 0.1704, Train Accuracy: 0.9394
# Validation Loss: 0.3770, Validation Accuracy: 0.8925
# Epoch 18
# Train Loss: 0.1639, Train Accuracy: 0.9382
# Validation Loss: 0.3711, Validation Accuracy: 0.8891
# Epoch 19
# Train Loss: 0.1609, Train Accuracy: 0.9400
# Validation Loss: 0.3836, Validation Accuracy: 0.8858
# Epoch 20
# Train Loss: 0.1544, Train Accuracy: 0.9420
# Validation Loss: 0.3937, Validation Accuracy: 0.8840
# Epoch 21
# Train Loss: 0.1499, Train Accuracy: 0.9455
# Validation Loss: 0.3863, Validation Accuracy: 0.8900
# Epoch 22
# Train Loss: 0.1473, Train Accuracy: 0.9538
# Validation Loss: 0.3818, Validation Accuracy: 0.8944
# Epoch 23
# Train Loss: 0.1468, Train Accuracy: 0.9563
# Validation Loss: 0.3713, Validation Accuracy: 0.8974
# Epoch 24
# Train Loss: 0.1386, Train Accuracy: 0.9505
# Validation Loss: 0.4063, Validation Accuracy: 0.8890
# Epoch 25
# Train Loss: 0.1393, Train Accuracy: 0.9559
# Validation Loss: 0.3924, Validation Accuracy: 0.8946
# Epoch 26
# Train Loss: 0.1322, Train Accuracy: 0.9567
# Validation Loss: 0.4217, Validation Accuracy: 0.8922
# Epoch 27
# Train Loss: 0.1298, Train Accuracy: 0.9534
# Validation Loss: 0.4348, Validation Accuracy: 0.8888
# Epoch 28
# Train Loss: 0.1268, Train Accuracy: 0.9579
# Validation Loss: 0.4166, Validation Accuracy: 0.8957
# Epoch 29
# Train Loss: 0.1211, Train Accuracy: 0.9572
# Validation Loss: 0.4213, Validation Accuracy: 0.8941
# Epoch 30
# Train Loss: 0.1210, Train Accuracy: 0.9545
# Validation Loss: 0.4435, Validation Accuracy: 0.8917

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with One Hidden Layer')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with One Hidden Layer')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-9-859f9414bfa1>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Model dengan Dua Hidden Layer

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Dua hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Linear(1000, 1000),
        nn.ReLU(),
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    batch_loss = loss_fn(prediction, y)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.4781, Train Accuracy: 0.8609
# Validation Loss: 0.4400, Validation Accuracy: 0.8464
# Epoch 2
# Train Loss: 0.3606, Train Accuracy: 0.8719
# Validation Loss: 0.4033, Validation Accuracy: 0.8527
# Epoch 3
# Train Loss: 0.3215, Train Accuracy: 0.8959
# Validation Loss: 0.3422, Validation Accuracy: 0.8762
# Epoch 4
# Train Loss: 0.2949, Train Accuracy: 0.8982
# Validation Loss: 0.3443, Validation Accuracy: 0.8758
# Epoch 5
# Train Loss: 0.2786, Train Accuracy: 0.9006
# Validation Loss: 0.3474, Validation Accuracy: 0.8759
# Epoch 6
# Train Loss: 0.2630, Train Accuracy: 0.9107
# Validation Loss: 0.3264, Validation Accuracy: 0.8825
# Epoch 7
# Train Loss: 0.2480, Train Accuracy: 0.9169
# Validation Loss: 0.3275, Validation Accuracy: 0.8847
# Epoch 8
# Train Loss: 0.2371, Train Accuracy: 0.9064
# Validation Loss: 0.3673, Validation Accuracy: 0.8769
# Epoch 9
# Train Loss: 0.2293, Train Accuracy: 0.9063
# Validation Loss: 0.3740, Validation Accuracy: 0.8765
# Epoch 10
# Train Loss: 0.2201, Train Accuracy: 0.9117
# Validation Loss: 0.3889, Validation Accuracy: 0.8745
# Epoch 11
# Train Loss: 0.2097, Train Accuracy: 0.9253
# Validation Loss: 0.3593, Validation Accuracy: 0.8877
# Epoch 12
# Train Loss: 0.2016, Train Accuracy: 0.9301
# Validation Loss: 0.3512, Validation Accuracy: 0.8911
# Epoch 13
# Train Loss: 0.1957, Train Accuracy: 0.9351
# Validation Loss: 0.3442, Validation Accuracy: 0.8917
# Epoch 14
# Train Loss: 0.1871, Train Accuracy: 0.9332
# Validation Loss: 0.3642, Validation Accuracy: 0.8882
# Epoch 15
# Train Loss: 0.1829, Train Accuracy: 0.9360
# Validation Loss: 0.3847, Validation Accuracy: 0.8931
# Epoch 16
# Train Loss: 0.1756, Train Accuracy: 0.9276
# Validation Loss: 0.4444, Validation Accuracy: 0.8847
# Epoch 17
# Train Loss: 0.1717, Train Accuracy: 0.9413
# Validation Loss: 0.4160, Validation Accuracy: 0.8933
# Epoch 18
# Train Loss: 0.1623, Train Accuracy: 0.9458
# Validation Loss: 0.4023, Validation Accuracy: 0.8933
# Epoch 19
# Train Loss: 0.1597, Train Accuracy: 0.9357
# Validation Loss: 0.4362, Validation Accuracy: 0.8879
# Epoch 20
# Train Loss: 0.1591, Train Accuracy: 0.9438
# Validation Loss: 0.4542, Validation Accuracy: 0.8927
# Epoch 21
# Train Loss: 0.1521, Train Accuracy: 0.9451
# Validation Loss: 0.4566, Validation Accuracy: 0.8916
# Epoch 22
# Train Loss: 0.1482, Train Accuracy: 0.9428
# Validation Loss: 0.4416, Validation Accuracy: 0.8854
# Epoch 23
# Train Loss: 0.1451, Train Accuracy: 0.9511
# Validation Loss: 0.4477, Validation Accuracy: 0.8921
# Epoch 24
# Train Loss: 0.1400, Train Accuracy: 0.9465
# Validation Loss: 0.4944, Validation Accuracy: 0.8920
# Epoch 25
# Train Loss: 0.1388, Train Accuracy: 0.9509
# Validation Loss: 0.5010, Validation Accuracy: 0.8870
# Epoch 26
# Train Loss: 0.1292, Train Accuracy: 0.9521
# Validation Loss: 0.4694, Validation Accuracy: 0.8921
# Epoch 27
# Train Loss: 0.1301, Train Accuracy: 0.9440
# Validation Loss: 0.5086, Validation Accuracy: 0.8858
# Epoch 28
# Train Loss: 0.1261, Train Accuracy: 0.9584
# Validation Loss: 0.5481, Validation Accuracy: 0.8960
# Epoch 29
# Train Loss: 0.1283, Train Accuracy: 0.9522
# Validation Loss: 0.5341, Validation Accuracy: 0.8861
# Epoch 30
# Train Loss: 0.1202, Train Accuracy: 0.9573
# Validation Loss: 0.5211, Validation Accuracy: 0.8927

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with Two Hidden Layer')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with Two Hidden Layer')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-12-5bbe63765afd>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
