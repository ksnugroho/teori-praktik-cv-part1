# %% [markdown]
# <a href="https://colab.research.google.com/github/ksnugroho/teori-praktik-cv-part1/blob/main/Bagian_1_Bab_4_4_2_Dampak_Penambahan_Regularisasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Mengunduh Dataset

# %%
data_folder = './data/FMNIST'

train_data = datasets.FashionMNIST(data_folder, download=True, train=True)
val_data = datasets.FashionMNIST(data_folder, download=True, train=False)

tr_images, tr_targets = train_data.data, train_data.targets
val_images, val_targets = val_data.data, val_data.targets
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 8.97MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 177kB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.23MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 21.7MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw

# %%
class FMNISTDataset(Dataset):
    def __init__(self, x, y):
        x = x.float() / 255
        x = x.view(-1, 28*28)
        self.x, self.y = x, y

    def __getitem__(self, ix):
        x, y = self.x[ix], self.y[ix]
        return x.to(device), y.to(device)

    def __len__(self):
        return len(self.x)

# %% [markdown]
# # Tanpa Regularisasi

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Satu hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    batch_loss = loss_fn(prediction, y)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.4761, Train Accuracy: 0.8620
# Validation Loss: 0.4143, Validation Accuracy: 0.8488
# Epoch 2
# Train Loss: 0.3580, Train Accuracy: 0.8800
# Validation Loss: 0.3920, Validation Accuracy: 0.8618
# Epoch 3
# Train Loss: 0.3208, Train Accuracy: 0.8997
# Validation Loss: 0.3397, Validation Accuracy: 0.8799
# Epoch 4
# Train Loss: 0.2976, Train Accuracy: 0.8976
# Validation Loss: 0.3483, Validation Accuracy: 0.8728
# Epoch 5
# Train Loss: 0.2780, Train Accuracy: 0.8972
# Validation Loss: 0.3732, Validation Accuracy: 0.8694
# Epoch 6
# Train Loss: 0.2626, Train Accuracy: 0.9026
# Validation Loss: 0.3436, Validation Accuracy: 0.8756
# Epoch 7
# Train Loss: 0.2500, Train Accuracy: 0.9188
# Validation Loss: 0.3200, Validation Accuracy: 0.8859
# Epoch 8
# Train Loss: 0.2390, Train Accuracy: 0.9182
# Validation Loss: 0.3360, Validation Accuracy: 0.8836
# Epoch 9
# Train Loss: 0.2274, Train Accuracy: 0.9232
# Validation Loss: 0.3356, Validation Accuracy: 0.8827
# Epoch 10
# Train Loss: 0.2221, Train Accuracy: 0.9237
# Validation Loss: 0.3372, Validation Accuracy: 0.8845
# Epoch 11
# Train Loss: 0.2090, Train Accuracy: 0.9203
# Validation Loss: 0.3708, Validation Accuracy: 0.8801
# Epoch 12
# Train Loss: 0.2023, Train Accuracy: 0.9308
# Validation Loss: 0.3408, Validation Accuracy: 0.8844
# Epoch 13
# Train Loss: 0.1928, Train Accuracy: 0.9159
# Validation Loss: 0.3836, Validation Accuracy: 0.8727
# Epoch 14
# Train Loss: 0.1909, Train Accuracy: 0.9329
# Validation Loss: 0.3399, Validation Accuracy: 0.8917
# Epoch 15
# Train Loss: 0.1809, Train Accuracy: 0.9359
# Validation Loss: 0.3602, Validation Accuracy: 0.8880
# Epoch 16
# Train Loss: 0.1756, Train Accuracy: 0.9385
# Validation Loss: 0.3601, Validation Accuracy: 0.8930
# Epoch 17
# Train Loss: 0.1697, Train Accuracy: 0.9331
# Validation Loss: 0.3935, Validation Accuracy: 0.8797
# Epoch 18
# Train Loss: 0.1674, Train Accuracy: 0.9481
# Validation Loss: 0.3611, Validation Accuracy: 0.8956
# Epoch 19
# Train Loss: 0.1599, Train Accuracy: 0.9441
# Validation Loss: 0.3702, Validation Accuracy: 0.8903
# Epoch 20
# Train Loss: 0.1568, Train Accuracy: 0.9476
# Validation Loss: 0.3667, Validation Accuracy: 0.8950
# Epoch 21
# Train Loss: 0.1493, Train Accuracy: 0.9461
# Validation Loss: 0.3957, Validation Accuracy: 0.8924
# Epoch 22
# Train Loss: 0.1436, Train Accuracy: 0.9494
# Validation Loss: 0.4019, Validation Accuracy: 0.8922
# Epoch 23
# Train Loss: 0.1438, Train Accuracy: 0.9527
# Validation Loss: 0.3934, Validation Accuracy: 0.8913
# Epoch 24
# Train Loss: 0.1396, Train Accuracy: 0.9488
# Validation Loss: 0.4218, Validation Accuracy: 0.8895
# Epoch 25
# Train Loss: 0.1345, Train Accuracy: 0.9562
# Validation Loss: 0.3952, Validation Accuracy: 0.8925
# Epoch 26
# Train Loss: 0.1280, Train Accuracy: 0.9468
# Validation Loss: 0.4486, Validation Accuracy: 0.8835
# Epoch 27
# Train Loss: 0.1303, Train Accuracy: 0.9590
# Validation Loss: 0.4209, Validation Accuracy: 0.8886
# Epoch 28
# Train Loss: 0.1261, Train Accuracy: 0.9545
# Validation Loss: 0.4280, Validation Accuracy: 0.8887
# Epoch 29
# Train Loss: 0.1218, Train Accuracy: 0.9574
# Validation Loss: 0.4185, Validation Accuracy: 0.8905
# Epoch 30
# Train Loss: 0.1165, Train Accuracy: 0.9619
# Validation Loss: 0.4314, Validation Accuracy: 0.8942

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with No Regularization')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with No Regularization')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-6-4f14b42eccfd>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Regularisasi L1

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Satu hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    # L1 Regularization
    l1_regularization = 0
    for param in model.parameters():
        l1_regularization += torch.norm(param, 1)
    batch_loss = loss_fn(prediction, y) + 0.0001 * l1_regularization
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.8829, Train Accuracy: 0.8478
# Validation Loss: 0.4656, Validation Accuracy: 0.8351
# Epoch 2
# Train Loss: 0.6128, Train Accuracy: 0.8626
# Validation Loss: 0.4350, Validation Accuracy: 0.8446
# Epoch 3
# Train Loss: 0.5404, Train Accuracy: 0.8673
# Validation Loss: 0.4173, Validation Accuracy: 0.8536
# Epoch 4
# Train Loss: 0.5207, Train Accuracy: 0.8659
# Validation Loss: 0.4141, Validation Accuracy: 0.8502
# Epoch 5
# Train Loss: 0.5099, Train Accuracy: 0.8779
# Validation Loss: 0.3824, Validation Accuracy: 0.8604
# Epoch 6
# Train Loss: 0.4866, Train Accuracy: 0.8720
# Validation Loss: 0.3995, Validation Accuracy: 0.8562
# Epoch 7
# Train Loss: 0.4822, Train Accuracy: 0.8721
# Validation Loss: 0.4044, Validation Accuracy: 0.8598
# Epoch 8
# Train Loss: 0.4760, Train Accuracy: 0.8825
# Validation Loss: 0.3802, Validation Accuracy: 0.8656
# Epoch 9
# Train Loss: 0.4756, Train Accuracy: 0.8727
# Validation Loss: 0.4029, Validation Accuracy: 0.8520
# Epoch 10
# Train Loss: 0.4692, Train Accuracy: 0.8883
# Validation Loss: 0.3630, Validation Accuracy: 0.8666
# Epoch 11
# Train Loss: 0.4599, Train Accuracy: 0.8902
# Validation Loss: 0.3627, Validation Accuracy: 0.8704
# Epoch 12
# Train Loss: 0.4624, Train Accuracy: 0.8876
# Validation Loss: 0.3675, Validation Accuracy: 0.8691
# Epoch 13
# Train Loss: 0.4622, Train Accuracy: 0.8805
# Validation Loss: 0.3805, Validation Accuracy: 0.8631
# Epoch 14
# Train Loss: 0.4546, Train Accuracy: 0.8876
# Validation Loss: 0.3684, Validation Accuracy: 0.8685
# Epoch 15
# Train Loss: 0.4486, Train Accuracy: 0.8736
# Validation Loss: 0.4114, Validation Accuracy: 0.8547
# Epoch 16
# Train Loss: 0.4571, Train Accuracy: 0.8708
# Validation Loss: 0.4005, Validation Accuracy: 0.8556
# Epoch 17
# Train Loss: 0.4507, Train Accuracy: 0.8923
# Validation Loss: 0.3513, Validation Accuracy: 0.8739
# Epoch 18
# Train Loss: 0.4472, Train Accuracy: 0.8911
# Validation Loss: 0.3596, Validation Accuracy: 0.8706
# Epoch 19
# Train Loss: 0.4476, Train Accuracy: 0.8936
# Validation Loss: 0.3574, Validation Accuracy: 0.8676
# Epoch 20
# Train Loss: 0.4432, Train Accuracy: 0.8899
# Validation Loss: 0.3701, Validation Accuracy: 0.8657
# Epoch 21
# Train Loss: 0.4420, Train Accuracy: 0.8934
# Validation Loss: 0.3597, Validation Accuracy: 0.8700
# Epoch 22
# Train Loss: 0.4449, Train Accuracy: 0.8920
# Validation Loss: 0.3592, Validation Accuracy: 0.8703
# Epoch 23
# Train Loss: 0.4452, Train Accuracy: 0.8904
# Validation Loss: 0.3669, Validation Accuracy: 0.8686
# Epoch 24
# Train Loss: 0.4442, Train Accuracy: 0.8856
# Validation Loss: 0.3763, Validation Accuracy: 0.8631
# Epoch 25
# Train Loss: 0.4370, Train Accuracy: 0.8946
# Validation Loss: 0.3538, Validation Accuracy: 0.8744
# Epoch 26
# Train Loss: 0.4366, Train Accuracy: 0.8911
# Validation Loss: 0.3711, Validation Accuracy: 0.8654
# Epoch 27
# Train Loss: 0.4397, Train Accuracy: 0.8935
# Validation Loss: 0.3572, Validation Accuracy: 0.8693
# Epoch 28
# Train Loss: 0.4377, Train Accuracy: 0.8950
# Validation Loss: 0.3539, Validation Accuracy: 0.8702
# Epoch 29
# Train Loss: 0.4347, Train Accuracy: 0.8957
# Validation Loss: 0.3568, Validation Accuracy: 0.8716
# Epoch 30
# Train Loss: 0.4348, Train Accuracy: 0.8911
# Validation Loss: 0.3596, Validation Accuracy: 0.8698

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with L1 Regularization')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with L1 Regularization')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-9-f4728bf19c87>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Regularisasi L2

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Satu hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    # L2 Regularization
    l2_regularization = 0
    for param in model.parameters():
        l2_regularization += torch.norm(param, 2)
    batch_loss = loss_fn(prediction, y) + 0.01 * l2_regularization
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.7148, Train Accuracy: 0.8438
# Validation Loss: 0.4772, Validation Accuracy: 0.8293
# Epoch 2
# Train Loss: 0.6269, Train Accuracy: 0.8616
# Validation Loss: 0.4274, Validation Accuracy: 0.8438
# Epoch 3
# Train Loss: 0.5915, Train Accuracy: 0.8654
# Validation Loss: 0.4155, Validation Accuracy: 0.8488
# Epoch 4
# Train Loss: 0.5697, Train Accuracy: 0.8666
# Validation Loss: 0.4278, Validation Accuracy: 0.8477
# Epoch 5
# Train Loss: 0.5592, Train Accuracy: 0.8654
# Validation Loss: 0.4208, Validation Accuracy: 0.8426
# Epoch 6
# Train Loss: 0.5499, Train Accuracy: 0.8665
# Validation Loss: 0.4183, Validation Accuracy: 0.8492
# Epoch 7
# Train Loss: 0.5409, Train Accuracy: 0.8800
# Validation Loss: 0.3964, Validation Accuracy: 0.8591
# Epoch 8
# Train Loss: 0.5354, Train Accuracy: 0.8804
# Validation Loss: 0.3913, Validation Accuracy: 0.8576
# Epoch 9
# Train Loss: 0.5326, Train Accuracy: 0.8842
# Validation Loss: 0.3791, Validation Accuracy: 0.8657
# Epoch 10
# Train Loss: 0.5323, Train Accuracy: 0.8682
# Validation Loss: 0.4194, Validation Accuracy: 0.8487
# Epoch 11
# Train Loss: 0.5281, Train Accuracy: 0.8865
# Validation Loss: 0.3777, Validation Accuracy: 0.8628
# Epoch 12
# Train Loss: 0.5271, Train Accuracy: 0.8867
# Validation Loss: 0.3775, Validation Accuracy: 0.8630
# Epoch 13
# Train Loss: 0.5257, Train Accuracy: 0.8909
# Validation Loss: 0.3703, Validation Accuracy: 0.8674
# Epoch 14
# Train Loss: 0.5226, Train Accuracy: 0.8935
# Validation Loss: 0.3616, Validation Accuracy: 0.8722
# Epoch 15
# Train Loss: 0.5224, Train Accuracy: 0.8831
# Validation Loss: 0.3885, Validation Accuracy: 0.8590
# Epoch 16
# Train Loss: 0.5211, Train Accuracy: 0.8916
# Validation Loss: 0.3660, Validation Accuracy: 0.8680
# Epoch 17
# Train Loss: 0.5186, Train Accuracy: 0.8899
# Validation Loss: 0.3738, Validation Accuracy: 0.8657
# Epoch 18
# Train Loss: 0.5173, Train Accuracy: 0.8830
# Validation Loss: 0.3835, Validation Accuracy: 0.8622
# Epoch 19
# Train Loss: 0.5179, Train Accuracy: 0.8927
# Validation Loss: 0.3648, Validation Accuracy: 0.8706
# Epoch 20
# Train Loss: 0.5187, Train Accuracy: 0.8864
# Validation Loss: 0.3761, Validation Accuracy: 0.8672
# Epoch 21
# Train Loss: 0.5173, Train Accuracy: 0.8907
# Validation Loss: 0.3671, Validation Accuracy: 0.8709
# Epoch 22
# Train Loss: 0.5168, Train Accuracy: 0.8800
# Validation Loss: 0.3990, Validation Accuracy: 0.8604
# Epoch 23
# Train Loss: 0.5176, Train Accuracy: 0.8871
# Validation Loss: 0.3771, Validation Accuracy: 0.8656
# Epoch 24
# Train Loss: 0.5161, Train Accuracy: 0.8886
# Validation Loss: 0.3739, Validation Accuracy: 0.8658
# Epoch 25
# Train Loss: 0.5153, Train Accuracy: 0.8625
# Validation Loss: 0.4246, Validation Accuracy: 0.8414
# Epoch 26
# Train Loss: 0.5150, Train Accuracy: 0.8943
# Validation Loss: 0.3643, Validation Accuracy: 0.8718
# Epoch 27
# Train Loss: 0.5144, Train Accuracy: 0.8959
# Validation Loss: 0.3547, Validation Accuracy: 0.8734
# Epoch 28
# Train Loss: 0.5130, Train Accuracy: 0.8930
# Validation Loss: 0.3689, Validation Accuracy: 0.8685
# Epoch 29
# Train Loss: 0.5164, Train Accuracy: 0.8861
# Validation Loss: 0.3868, Validation Accuracy: 0.8619
# Epoch 30
# Train Loss: 0.5140, Train Accuracy: 0.8883
# Validation Loss: 0.3752, Validation Accuracy: 0.8646

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with L2 Regularization')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with L2 Regularization')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-12-ca0041b3b646>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
