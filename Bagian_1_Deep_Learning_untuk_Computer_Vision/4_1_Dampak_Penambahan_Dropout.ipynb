# %% [markdown]
# <a href="https://colab.research.google.com/github/ksnugroho/teori-praktik-cv-part1/blob/main/Bagian_1_Bab_4_4_1_Dampak_Penambahan_Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Mengunduh Dataset

# %%
data_folder = './data/FMNIST'

train_data = datasets.FashionMNIST(data_folder, download=True, train=True)
val_data = datasets.FashionMNIST(data_folder, download=True, train=False)

tr_images, tr_targets = train_data.data, train_data.targets
val_images, val_targets = val_data.data, val_data.targets
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 11.0MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 172kB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.20MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FMNIST/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 20.9MB/s]
# Extracting ./data/FMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FMNIST/FashionMNIST/raw

# %%
class FMNISTDataset(Dataset):
    def __init__(self, x, y):
        x = x.float() / 255
        x = x.view(-1, 28*28)
        self.x, self.y = x, y

    def __getitem__(self, ix):
        x, y = self.x[ix], self.y[ix]
        return x.to(device), y.to(device)

    def __len__(self):
        return len(self.x)

# %% [markdown]
# # Tanpa Dropout

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Satu hidden layer
def get_model():
    model = nn.Sequential(
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    batch_loss = loss_fn(prediction, y)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.4754, Train Accuracy: 0.8566
# Validation Loss: 0.4406, Validation Accuracy: 0.8436
# Epoch 2
# Train Loss: 0.3574, Train Accuracy: 0.8888
# Validation Loss: 0.3692, Validation Accuracy: 0.8706
# Epoch 3
# Train Loss: 0.3203, Train Accuracy: 0.8859
# Validation Loss: 0.3765, Validation Accuracy: 0.8659
# Epoch 4
# Train Loss: 0.2938, Train Accuracy: 0.8938
# Validation Loss: 0.3531, Validation Accuracy: 0.8725
# Epoch 5
# Train Loss: 0.2787, Train Accuracy: 0.9036
# Validation Loss: 0.3486, Validation Accuracy: 0.8760
# Epoch 6
# Train Loss: 0.2646, Train Accuracy: 0.9134
# Validation Loss: 0.3343, Validation Accuracy: 0.8816
# Epoch 7
# Train Loss: 0.2522, Train Accuracy: 0.9125
# Validation Loss: 0.3355, Validation Accuracy: 0.8826
# Epoch 8
# Train Loss: 0.2397, Train Accuracy: 0.9163
# Validation Loss: 0.3300, Validation Accuracy: 0.8844
# Epoch 9
# Train Loss: 0.2280, Train Accuracy: 0.9187
# Validation Loss: 0.3504, Validation Accuracy: 0.8813
# Epoch 10
# Train Loss: 0.2195, Train Accuracy: 0.9258
# Validation Loss: 0.3380, Validation Accuracy: 0.8883
# Epoch 11
# Train Loss: 0.2113, Train Accuracy: 0.9242
# Validation Loss: 0.3441, Validation Accuracy: 0.8853
# Epoch 12
# Train Loss: 0.2041, Train Accuracy: 0.9267
# Validation Loss: 0.3528, Validation Accuracy: 0.8879
# Epoch 13
# Train Loss: 0.1976, Train Accuracy: 0.9155
# Validation Loss: 0.3895, Validation Accuracy: 0.8727
# Epoch 14
# Train Loss: 0.1879, Train Accuracy: 0.9221
# Validation Loss: 0.3758, Validation Accuracy: 0.8756
# Epoch 15
# Train Loss: 0.1826, Train Accuracy: 0.9392
# Validation Loss: 0.3557, Validation Accuracy: 0.8911
# Epoch 16
# Train Loss: 0.1773, Train Accuracy: 0.9439
# Validation Loss: 0.3452, Validation Accuracy: 0.8924
# Epoch 17
# Train Loss: 0.1735, Train Accuracy: 0.9334
# Validation Loss: 0.3887, Validation Accuracy: 0.8859
# Epoch 18
# Train Loss: 0.1653, Train Accuracy: 0.9431
# Validation Loss: 0.3743, Validation Accuracy: 0.8928
# Epoch 19
# Train Loss: 0.1615, Train Accuracy: 0.9390
# Validation Loss: 0.3825, Validation Accuracy: 0.8809
# Epoch 20
# Train Loss: 0.1550, Train Accuracy: 0.9482
# Validation Loss: 0.3712, Validation Accuracy: 0.8935
# Epoch 21
# Train Loss: 0.1517, Train Accuracy: 0.9472
# Validation Loss: 0.3789, Validation Accuracy: 0.8931
# Epoch 22
# Train Loss: 0.1475, Train Accuracy: 0.9491
# Validation Loss: 0.4131, Validation Accuracy: 0.8888
# Epoch 23
# Train Loss: 0.1448, Train Accuracy: 0.9506
# Validation Loss: 0.3891, Validation Accuracy: 0.8931
# Epoch 24
# Train Loss: 0.1390, Train Accuracy: 0.9542
# Validation Loss: 0.4127, Validation Accuracy: 0.8930
# Epoch 25
# Train Loss: 0.1342, Train Accuracy: 0.9545
# Validation Loss: 0.4205, Validation Accuracy: 0.8936
# Epoch 26
# Train Loss: 0.1332, Train Accuracy: 0.9547
# Validation Loss: 0.4127, Validation Accuracy: 0.8940
# Epoch 27
# Train Loss: 0.1282, Train Accuracy: 0.9546
# Validation Loss: 0.4308, Validation Accuracy: 0.8897
# Epoch 28
# Train Loss: 0.1249, Train Accuracy: 0.9549
# Validation Loss: 0.4413, Validation Accuracy: 0.8894
# Epoch 29
# Train Loss: 0.1251, Train Accuracy: 0.9573
# Validation Loss: 0.4317, Validation Accuracy: 0.8945
# Epoch 30
# Train Loss: 0.1191, Train Accuracy: 0.9495
# Validation Loss: 0.4510, Validation Accuracy: 0.8880

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with No Dropout')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with No Dropout')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-6-2f2d44fc2aa7>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Penambahan Dropout

# %%
def get_data():
    train = FMNISTDataset(tr_images, tr_targets)
    trn_dl = DataLoader(train, batch_size=32, shuffle=True)
    val = FMNISTDataset(val_images, val_targets)
    val_dl = DataLoader(val, batch_size=len(val_images), shuffle=False)
    return trn_dl, val_dl

# Satu hidden layer
def get_model():
    model = nn.Sequential(
        nn.Dropout(0.25),               # Dropout
        nn.Linear(28 * 28, 1000),
        nn.ReLU(),
        nn.Dropout(0.25),               # Dropout
        nn.Linear(1000, 10)
    ).to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

def train_batch(x, y, model, opt, loss_fn):
    model.train()
    prediction = model(x)
    batch_loss = loss_fn(prediction, y)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

def accuracy(x, y, model):
    model.eval()
    with torch.no_grad():
        prediction = model(x)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == y
    return is_correct.cpu().numpy().tolist()

def val_loss(x, y, model):
    with torch.no_grad():
        prediction = model(x)
        val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
trn_dl, val_dl = get_data()
model, loss_fn, optimizer = get_model()

train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

for epoch in range(30):
    print(f"Epoch {epoch + 1}")
    train_epoch_losses, train_epoch_accuracies = [], []

    for x, y in trn_dl:
        batch_loss = train_batch(x, y, model, optimizer, loss_fn)
        train_epoch_losses.append(batch_loss)
    train_epoch_loss = np.array(train_epoch_losses).mean()

    for x, y in trn_dl:
        is_correct = accuracy(x, y, model)
        train_epoch_accuracies.extend(is_correct)
    train_epoch_accuracy = np.mean(train_epoch_accuracies)

    for x, y in val_dl:
        val_is_correct = accuracy(x, y, model)
        validation_loss = val_loss(x, y, model)
    val_epoch_accuracy = np.mean(val_is_correct)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)

    print(f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}")
    print(f"Validation Loss: {validation_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.4f}")
# Out:
# Epoch 1
# Train Loss: 0.5381, Train Accuracy: 0.8562
# Validation Loss: 0.4384, Validation Accuracy: 0.8404
# Epoch 2
# Train Loss: 0.4290, Train Accuracy: 0.8649
# Validation Loss: 0.4080, Validation Accuracy: 0.8530
# Epoch 3
# Train Loss: 0.3974, Train Accuracy: 0.8740
# Validation Loss: 0.3974, Validation Accuracy: 0.8551
# Epoch 4
# Train Loss: 0.3777, Train Accuracy: 0.8843
# Validation Loss: 0.3711, Validation Accuracy: 0.8666
# Epoch 5
# Train Loss: 0.3626, Train Accuracy: 0.8903
# Validation Loss: 0.3608, Validation Accuracy: 0.8701
# Epoch 6
# Train Loss: 0.3566, Train Accuracy: 0.8908
# Validation Loss: 0.3579, Validation Accuracy: 0.8712
# Epoch 7
# Train Loss: 0.3483, Train Accuracy: 0.8976
# Validation Loss: 0.3432, Validation Accuracy: 0.8746
# Epoch 8
# Train Loss: 0.3369, Train Accuracy: 0.8995
# Validation Loss: 0.3381, Validation Accuracy: 0.8775
# Epoch 9
# Train Loss: 0.3329, Train Accuracy: 0.8999
# Validation Loss: 0.3451, Validation Accuracy: 0.8764
# Epoch 10
# Train Loss: 0.3269, Train Accuracy: 0.9046
# Validation Loss: 0.3306, Validation Accuracy: 0.8795
# Epoch 11
# Train Loss: 0.3231, Train Accuracy: 0.8975
# Validation Loss: 0.3449, Validation Accuracy: 0.8735
# Epoch 12
# Train Loss: 0.3183, Train Accuracy: 0.9095
# Validation Loss: 0.3253, Validation Accuracy: 0.8833
# Epoch 13
# Train Loss: 0.3143, Train Accuracy: 0.9041
# Validation Loss: 0.3421, Validation Accuracy: 0.8780
# Epoch 14
# Train Loss: 0.3109, Train Accuracy: 0.9032
# Validation Loss: 0.3513, Validation Accuracy: 0.8747
# Epoch 15
# Train Loss: 0.3083, Train Accuracy: 0.9114
# Validation Loss: 0.3319, Validation Accuracy: 0.8822
# Epoch 16
# Train Loss: 0.3017, Train Accuracy: 0.9155
# Validation Loss: 0.3229, Validation Accuracy: 0.8872
# Epoch 17
# Train Loss: 0.3019, Train Accuracy: 0.9124
# Validation Loss: 0.3297, Validation Accuracy: 0.8841
# Epoch 18
# Train Loss: 0.2978, Train Accuracy: 0.9113
# Validation Loss: 0.3429, Validation Accuracy: 0.8788
# Epoch 19
# Train Loss: 0.2959, Train Accuracy: 0.9137
# Validation Loss: 0.3357, Validation Accuracy: 0.8813
# Epoch 20
# Train Loss: 0.2921, Train Accuracy: 0.9138
# Validation Loss: 0.3345, Validation Accuracy: 0.8825
# Epoch 21
# Train Loss: 0.2890, Train Accuracy: 0.9188
# Validation Loss: 0.3273, Validation Accuracy: 0.8859
# Epoch 22
# Train Loss: 0.2907, Train Accuracy: 0.9136
# Validation Loss: 0.3363, Validation Accuracy: 0.8835
# Epoch 23
# Train Loss: 0.2844, Train Accuracy: 0.9161
# Validation Loss: 0.3383, Validation Accuracy: 0.8803
# Epoch 24
# Train Loss: 0.2874, Train Accuracy: 0.9190
# Validation Loss: 0.3314, Validation Accuracy: 0.8877
# Epoch 25
# Train Loss: 0.2824, Train Accuracy: 0.9184
# Validation Loss: 0.3284, Validation Accuracy: 0.8860
# Epoch 26
# Train Loss: 0.2810, Train Accuracy: 0.9216
# Validation Loss: 0.3292, Validation Accuracy: 0.8874
# Epoch 27
# Train Loss: 0.2784, Train Accuracy: 0.9204
# Validation Loss: 0.3291, Validation Accuracy: 0.8853
# Epoch 28
# Train Loss: 0.2794, Train Accuracy: 0.9209
# Validation Loss: 0.3352, Validation Accuracy: 0.8836
# Epoch 29
# Train Loss: 0.2768, Train Accuracy: 0.9248
# Validation Loss: 0.3360, Validation Accuracy: 0.8867
# Epoch 30
# Train Loss: 0.2776, Train Accuracy: 0.9262
# Validation Loss: 0.3386, Validation Accuracy: 0.8885

# %%
epochs = np.arange(30) + 1

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--')
plt.scatter(epochs, train_losses, color='red', label='Weight Update')
plt.title('Training and Validation Loss with Dropout')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', linestyle='--')
plt.scatter(epochs, train_accuracies, color='red', label='Weight Update')
plt.title('Training and Validation Accuracy with Dropout')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
plt.legend()

plt.show()
# Out:
# <ipython-input-9-9d45d3d0561a>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x * 100) for x in plt.gca().get_yticks()])
